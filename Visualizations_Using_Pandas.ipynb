# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_read_csv_IceCreamRatings = pd.read_csv(r'C:\Users\santa\Downloads\Panda Test\Ice Cream Ratings.csv')
df_read_csv_IceCreamRatings
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df_read_csv_IceCreamRatings.set_index('Date')
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df_read_csv_IceCreamRatings.plot()
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot(kind = 'line')
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df_read_csv_IceCreamRatings.plot(
    kind='line',
    title='Ice Cream Ratings',
    xlabel='Daily Rating',
    ylabel='Scores'
)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Rating', ylabel='Scores'>

# %%
df_read_csv_IceCreamRatings.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot(kind = 'bar', subplots = True)
# Out:
# array([<Axes: title={'center': 'Flavor Rating'}>,
#        <Axes: title={'center': 'Texture Rating'}>,
#        <Axes: title={'center': 'Overall Rating'}>], dtype=object)

# %%
df_read_csv_IceCreamRatings.plot(
    kind='bar',
    title='Ice Cream Ratings',
    xlabel='Daily Rating',
    ylabel='Scores'
)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Rating', ylabel='Scores'>

# %%
df_read_csv_IceCreamRatings.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings['Flavor Rating'].plot(kind = 'bar', stacked = True)
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot.barh(stacked = True)
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot.scatter(x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df_read_csv_IceCreamRatings.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df_read_csv_IceCreamRatings.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100, color = 'Red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df_read_csv_IceCreamRatings.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_read_csv_IceCreamRatings.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_read_csv_IceCreamRatings.boxplot()
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot.area()
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot.area(figsize = [10,5])
# Out:
# <Axes: >

# %%
df_read_csv_IceCreamRatings.plot.pie(y = 'Overall Rating')
# Out:
# <Axes: ylabel='Overall Rating'>

# %%
df_read_csv_IceCreamRatings.plot.pie(y = 'Overall Rating', figsize = [10,10])
# Out:
# <Axes: ylabel='Overall Rating'>

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('tableau-colorblind10')

# %%
df_read_csv_IceCreamRatings.plot.pie(y = 'Overall Rating')
# Out:
# <Axes: ylabel='Overall Rating'>
