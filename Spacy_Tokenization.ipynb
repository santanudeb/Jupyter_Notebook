# %%
import spacy

# %%
nlp = spacy.blank("en")
doc1 = nlp("Red roses blue sky $ two yellow birds")

doc2 = nlp('''"Let's go to N.Y.!"''')

doc3 = nlp("123 roses blue sky yellow")

# %%
for token1 in doc1 :
    print(token1)
# Out:
# Red
# roses
# blue
# sky
# yellow
# birds

# %%
doc1[3]
# Out:
# sky

# %%
doc1[-2]
# Out:
# yellow

# %%
for token2 in doc2 :
    print(token2)
# Out:
# "
# Let
# 's
# go
# to
# N.Y.
# !
# "

# %%
doc1[1:5]
# Out:
# roses blue sky yellow

# %%
token0 = doc3[0]

# %%
type(token0)
# Out:
# spacy.tokens.token.Token

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
doc[0].is_alpha
# Out:
# True

# %%
token0.like_num
# Out:
# False

# %%
doc1[-3]
# Out:
# two

# %%
doc1[-3].like_num
# Out:
# True

# %%
doc1[-4].is_currency
# Out:
# True

# %%
for token in doc:
    print(token, "==>", "index: ", token.i,
          "is_alpha:", token.is_alpha,
          "is_punct:", token.is_punct,
          "like_num:", token.like_num,
          "is_currency:", token.is_currency,
         )
# Out:
# Red ==> index:  0 is_alpha: True is_punct: False like_num: False is_currency: False
# roses ==> index:  1 is_alpha: True is_punct: False like_num: False is_currency: False
# blue ==> index:  2 is_alpha: True is_punct: False like_num: False is_currency: False
# sky ==> index:  3 is_alpha: True is_punct: False like_num: False is_currency: False
# yellow ==> index:  4 is_alpha: True is_punct: False like_num: False is_currency: False
# birds ==> index:  5 is_alpha: True is_punct: False like_num: False is_currency: False

# %%
file_path = r"F:\Codes\NLP\students.txt"

with open(file_path, "r") as file:
    content = file.readlines()

print(content)
# Out:
# ['Dayton high school, 8th grade students information\n', '==================================================\n', '\n', 'Name\tbirth day   \temail\n', '-----\t------------\t------\n', 'Virat   5 June, 1882    virat@kohli.com\n', 'Maria\t12 April, 2001  maria@sharapova.com\n', 'Serena  24 June, 1998   serena@williams.com \n', 'Joe      1 May, 1997    joe@root.com\n', '\n', '\n', '\n']

# %%
content = ' '.join(content)
content
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
doc = nlp(content)

emails = []

for token in doc:
    if token.like_email:
        emails.append(token.text)

print(emails)
# Out:
# ['virat@kohli.com', 'maria@sharapova.com', 'serena@williams.com', 'joe@root.com']

# %%
nlp = spacy.blank("bn")

doc = nlp("তুমি আজ কেমন আছো ₹ 2000 ")

for token in doc :
    print(token, token.is_alpha, token.is_currency, token.like_num)
# Out:
# তুমি False False False
# আজ True False False
# কেমন False False False
# আছো False False False
# ₹ False True False
# 2000 False False True

# %%
doc = nlp("gimme more extra large cheese pizza")

tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'more', 'extra', 'large', 'cheese', 'pizza']

# %%
from spacy.symbols import ORTH

nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"}
])

doc = nlp("gimme double cheese extra large healthy pizza")

tokens = [token.text for token in doc]

tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("1st sentence about nothing. 2nd sentence about first sentence")

for sentence in doc.sents :
    print(sentence)
# Out:
# 1st sentence about nothing.
# 2nd sentence about first sentence
