# %%
import nltk
import spacy

# %%
# Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
    print(word, "|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet

# %%
# Lemmatization

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("eating eats eat ate adjustable rafting ability meeting better. bro brah")

for token in doc:
    print(token, "|", token.lemma_, "|", token.lemma)
# Out:
# eating | eat | 9837207709914848172
# eats | eat | 9837207709914848172
# eat | eat | 9837207709914848172
# ate | eat | 9837207709914848172
# adjustable | adjustable | 6033511944150694480
# rafting | raft | 7154368781129989833
# ability | ability | 11565809527369121409
# meeting | meet | 6880656908171229526
# better | well | 4525988469032889948
# . | . | 12646065887601541794
# bro | bro | 3493238095688267532
# brah | brah | 4077184355776670182

# %%
# Custom Lemmatization

# %%
ar = nlp.get_pipe('attribute_ruler')

ar.add([[{"TEXT": "bro"}], [{"TEXT": "brah"}]], {"LEMMA": "brother"})

doc = nlp("eating eats eat ate adjustable rafting ability meeting better. bro brah")

for token in doc:
    print(token, "|", token.lemma_, "|", token.lemma)
# Out:
# eating | eat | 9837207709914848172
# eats | eat | 9837207709914848172
# eat | eat | 9837207709914848172
# ate | eat | 9837207709914848172
# adjustable | adjustable | 6033511944150694480
# rafting | raft | 7154368781129989833
# ability | ability | 11565809527369121409
# meeting | meet | 6880656908171229526
# better | well | 4525988469032889948
# . | . | 12646065887601541794
# bro | brother | 18324768411243929287
# brah | brother | 18324768411243929287
