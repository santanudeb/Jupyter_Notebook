# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Stacy loves to stay home. wow ! $ 123 made make % _ etc")

for token in doc :
    print(token, " | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_," | ", spacy.explain(token.tag_))
# Out:
# Stacy  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# loves  |  VERB  |  verb  |  VBZ  |  verb, 3rd person singular present
# to  |  PART  |  particle  |  TO  |  infinitival "to"
# stay  |  VERB  |  verb  |  VB  |  verb, base form
# home  |  ADV  |  adverb  |  RB  |  adverb
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# wow  |  INTJ  |  interjection  |  UH  |  interjection
# !  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# $  |  SYM  |  symbol  |  $  |  symbol, currency
# 123  |  NUM  |  numeral  |  CD  |  cardinal number
# made  |  VERB  |  verb  |  VBD  |  verb, past tense
# make  |  VERB  |  verb  |  VB  |  verb, base form
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# _  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# etc  |  NOUN  |  noun  |  NN  |  noun, singular or mass

# %%
# filter token

# %%
filtered_token = []

for token in doc :
    if token.pos_ not in ["SPACE","PUNT","X"]:
        filtered_token.append(token)
        
filtered_token
# Out:
# [Stacy, loves, to, stay, home, ., wow, !, $, 123, made, make, %, _, etc]

# %%
# count

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {92: 4, 100: 4, 94: 1, 86: 1, 97: 2, 91: 1, 99: 1, 93: 1}

# %%
for k,v in count.items():
    print(doc.vocab[k].text," | ",v)
